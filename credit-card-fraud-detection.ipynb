# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# ### Task 2

# %% [markdown]
# #### Import Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#load dataset
credit_card=pd.read_csv('creditcard.csv')

# %%
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#checkind number of missing values in each column
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit and fradulent transactions
credit_card['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# This is unbalanced dataset

# %% [markdown]
# 0 -----> Normal Transaction
# 1 -----> Fraudulent Transaction

# %%
#seperating the data for analysis
legit=credit_card[credit_card.Class==0]
fraud=credit_card[credit_card.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#statistical info of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare the values for both Transactions
credit_card.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Under-Sampling

# %% [markdown]
# #### Build the sample dataset containing similar distribution of normal transaction and fradulent transaction The number of fradulent transactions are 492

# %%
legit_sample=legit.sample(n=492)

# %% [markdown]
# #### Concatenating two dataframes

# %%
df=pd.concat([legit_sample,fraud], axis=0)

# %%
df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 224109  143656.0  1.883975 -0.200921 -2.370848  0.611977  0.257184 -2.115312
# 2410      1973.0 -0.618886  0.920640  1.601404 -0.181557  0.664980  0.973345
# 283089  171367.0 -0.336732  0.991374 -1.264396 -1.445765  1.810833 -0.636539
# 36188    38428.0 -0.770577 -0.729658  0.990091 -2.137709  0.041093  1.049368
# 162338  115030.0  1.970427 -0.862636 -1.047626 -0.579424 -0.923276 -0.822861
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 224109  1.144218 -0.677110  0.236765  ...  0.374479  0.979092 -0.252706
# 2410    0.438220  0.458395 -0.578672  ... -0.076752  0.039130  0.131712
# 283089  1.630657 -0.525786 -2.109017  ... -0.368768 -0.367632 -0.497855
# 36188   0.158168  0.333237 -1.219253  ...  0.479570  0.880107  0.017784
# 162338 -0.866657 -0.077291 -0.278192  ...  0.339612  0.921640  0.043746
#
# ...

# %%
df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92319.469512 -0.029645  0.038065  0.012782 -0.020573  0.086963
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.077284  0.048897  0.005645 -0.065687  ... -0.005610 -0.002798
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.004021 -0.030975 -0.020929  0.008513 -0.025143  0.008282 -0.005659
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       85.653211
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Splitting the data into Features and Targets

# %%
X=df.drop(columns='Class',axis=1)
Y=df['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 224109  143656.0  1.883975 -0.200921 -2.370848  0.611977  0.257184 -2.115312
# 2410      1973.0 -0.618886  0.920640  1.601404 -0.181557  0.664980  0.973345
# 283089  171367.0 -0.336732  0.991374 -1.264396 -1.445765  1.810833 -0.636539
# 36188    38428.0 -0.770577 -0.729658  0.990091 -2.137709  0.041093  1.049368
# 162338  115030.0  1.970427 -0.862636 -1.047626 -0.579424 -0.923276 -0.822861
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 224109    0
# 2410      0
# 283089    0
# 36188     0
# 162338    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# #### Split the data into Training and Testing data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2, stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# #### Model Training

# %% [markdown]
# #### Logistic regression

# %%
model=LogisticRegression()

# %%
# training the model with training data

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\arunk\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# #### Accuracy score

# %%
#accuracy on training data
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on Training data: ',training_data_accuracy)
# Out:
# Accuracy on Training data:  0.9453621346886912

# %%
#accuracy on testing data
X_test_prediction=model.predict(X_test)
testing_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on Testing data: ',testing_data_accuracy)
# Out:
# Accuracy on Testing data:  0.9289340101522843

# %%
def predict_fraud(input_data, model, feature_names):
    # Convert input_data to DataFrame
    input_data_df = pd.DataFrame([input_data], columns=feature_names)
    
    prediction = model.predict(input_data_df)
    
    if prediction[0] == 0:
        return "The transaction is Legitimate"
    else:
        return "The transaction is Fraudulent"

# Get feature names and their ranges from the training data
feature_names = X.columns.tolist()
feature_ranges = {feature: (X[feature].min(), X[feature].max()) for feature in feature_names}

# User input
print("Please enter the following feature values:")
user_input = []
for feature in feature_names:
    min_val, max_val = feature_ranges[feature]
    value = float(input(f"Enter value for {feature} (range: {min_val} to {max_val}): "))
    user_input.append(value)

# Check if the input data has the correct number of features
if len(user_input) != len(feature_names):
    print(f"Error: Expected {len(feature_names)} features, but got {len(user_input)}")
else:
    print(predict_fraud(user_input, model, feature_names))
# Out:
# Please enter the following feature values:
# Enter value for Time (range: 46.0 to 172693.0):  34343
# Enter value for V1 (range: -30.552380043581 to 2.31188136838874):  2.443
# Enter value for V2 (range: -28.4166437773152 to 22.0577289904909):  12.43434
# Enter value for V3 (range: -31.1036848245812 to 3.04706915972856):  1.4343
# Enter value for V4 (range: -3.86301401149124 to 12.1146718424589):  11.33434
# Enter value for V5 (range: -22.105531524316 to 11.0950886001596):  10.3434
# Enter value for V6 (range: -6.40626663445964 to 6.47411462748849):  1.34343
# Enter value for V7 (range: -43.5572415712451 to 5.8921713986762):  -43.0
# Enter value for V8 (range: -41.0442609210741 to 20.0072083651213):  -39.232
# Enter value for V9 (range: -13.4340663182301 to 4.54384123942818):  -12.3434
# Enter value for V10 (range: -24.5882624372475 to 7.13594786604317):  2.4343
# Enter value for V11 (range: -2.46507028694406 to 12.0189131816199):  3.3434
# ...
